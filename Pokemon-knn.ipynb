# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trainDF = pd.read_csv('/content/drive/MyDrive/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Train')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-23-f765d51ab735> in <cell line: 1>()
# ----> 1 trainDF = pd.read_csv('/content/drive/MyDrive/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Train')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
trainDF.head()
# Out:
#    ImageId NameOfPokemon
# 0  296.jpg       Pikachu
# 1  297.jpg       Pikachu
# 2  298.jpg       Pikachu
# 3  299.jpg       Pikachu
# 4  300.jpg       Pikachu

# %%
trainDF.shape
# Out:
# (304, 2)

# %%
X = trainDF.iloc[:,0].values
y = trainDF.iloc[:,1].values

# %%
plt.figure()

for i in range(3):
  s1 = cv2.imread('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Train/Images/'+X[i])
  coloredImage = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  resizedImage = cv2.resize(coloredImage,(100,100))
  plt.subplot(2,3,i+1)
  plt.title("Hello I am"+ str(y[i]))
  plt.axis('off')
  plt.imshow(coloredImage)

# %%
def dist(image1, image2):
  return np.sum((image1-image2)**2)**0.5

# %%
def KNN(X,y, test_point, k=5):
  vals = []
  for i in range(30):
    trainImage = cv2.imread('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Train/Images/' + X[i])
    coloredTrainImage = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    resizedTrainImage = cv2.resize(coloredTrainImage,(100,100))
    distance = dist(resizedTrainImage,test_point)
    vals.append((distance, y[i]))
  vals = sorted(vals)
  vals = vals[:k]

  return vals

# %%
testDF = pd.read_csv('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Test/test.csv')
testData = testDF.values
z = testData[:,0]

plt.figure()

for i in range(47,53):
  testImage = cv2.imread('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Test/Images/' + z[i])
  coloredTestImage = cv2.cvtColor(testImage, cv2.COLOR_BGR2RGB)
  resizedTestImage = cv2.resize(coloredTestImage,(100,100))
  pred = KNN(X,y,resizedTestImage)
  print(pred)
  # plt.imshow(resizedTestImage)
  # plt.title("Toi la: " +max(pred)[1])
  # plt.axis('off')
  # plt.show
# Out:
# [(1775.4528999666536, 'Pikachu'), (1775.4528999666536, 'Pikachu'), (1775.4528999666536, 'Pikachu'), (1775.4528999666536, 'Pikachu'), (1775.4528999666536, 'Pikachu')]
# [(1477.7817836203017, 'Pikachu'), (1477.7817836203017, 'Pikachu'), (1477.7817836203017, 'Pikachu'), (1477.7817836203017, 'Pikachu'), (1477.7817836203017, 'Pikachu')]
# [(1305.283111052924, 'Pikachu'), (1305.283111052924, 'Pikachu'), (1305.283111052924, 'Pikachu'), (1305.283111052924, 'Pikachu'), (1305.283111052924, 'Pikachu')]
# [(1173.5339790564226, 'Pikachu'), (1173.5339790564226, 'Pikachu'), (1173.5339790564226, 'Pikachu'), (1173.5339790564226, 'Pikachu'), (1173.5339790564226, 'Pikachu')]
# [(1260.0785689789348, 'Pikachu'), (1260.0785689789348, 'Pikachu'), (1260.0785689789348, 'Pikachu'), (1260.0785689789348, 'Pikachu'), (1260.0785689789348, 'Pikachu')]
# ...

# %%
testDF.shape
# Out:
# (123, 1)

# %%
plt.imshow(rgb_image)
plt.axis('off')
plt.show()

# %%
crop = cv2.resize(rgb_image,(100,100))
plt.imshow(crop)
plt.axis('off')
plt.show()

# %% [markdown]
# # KNN

# %%
def dist(a1,a2):
    return np.sum((a1-a2)**2)**.5

# %%
def KNN(X,Y,test_point,k=5):
    tt =cv2.imread("Train/Images/" + X[0])
    t2 = cv2.resize(tt,(100,100))
    m=t2.shape[0]
    vals = []
    for i in range(300):
        con = cv2.imread("Train/Images/" + X[i])
        con1 = cv2.cvtColor(con, cv2.COLOR_BGR2RGB)
        con2 = cv2.resize(con1,(100,100))
        d = dist(con2,test_point)
        vals.append((d,Y[i]))

    vals = sorted(vals)
    vals = vals[:k]

    return vals

    #vals = np.array(vals[:k])
    #b= np.unique(vals[:,1],return_counts=True)
    #idx = np.argmax(b[i])
    #pred = b[0][idx]

    #return str(pred)

# %% [markdown]
# # Main Code

# %%
df = pd.read_csv('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Train/train.csv')

# %%
df.head()
# Out:
#    ImageId NameOfPokemon
# 0  296.jpg       Pikachu
# 1  297.jpg       Pikachu
# 2  298.jpg       Pikachu
# 3  299.jpg       Pikachu
# 4  300.jpg       Pikachu

# %%
df.shape
# Out:
# (304, 2)

# %%
data = df.values

# %%
Y = data[:,1]
X = data[:,0]

# %%
df1 = pd.read_csv('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Test/test.csv')
df1.head()
df1.shape
# Out:
# (123, 1)

# %%
data = df1.values
Z = data[:,0]

# %%
Z.shape
# Out:
# (123,)

# %%
plt.figure()
i=1
for i in range(4):
    s1 = cv2.imread('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Train/Images/' + X[i])
    s2 = cv2.cvtColor(s1, cv2.COLOR_BGR2RGB)
    c1 = cv2.resize(s2,(100,100))
    plt.subplot(2,5,i+1)
    plt.imshow(c1)
    plt.title("label: " + str(Y[i]))
    plt.axis('off')
    plt.show()

# %%
plt.figure()
for i in range(1,7):
    s1 = cv2.imread('/content/drive/MyDrive/ĐẠI HỌC KHÔNG HỌC ĐẠI/Thi Giac May Tinh/KNN - BÀI TOÁN PHÂN LỚP ẢNH/Test/Images/' + Z[i])
    s2 = cv2.cvtColor(s1, cv2.COLOR_BGR2RGB)
    c1 = cv2.resize(s2,(100,100))
    pred = KNN(X,Y,c1,10)
    print(pred)
    #plt.subplot(2,5,i+1)
    plt.imshow(c1)
    #plt.title("label: " + str(Y[i]))
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-325-db9b49105752> in <cell line: 2>()
#       4     s2 = cv2.cvtColor(s1, cv2.COLOR_BGR2RGB)
#       5     c1 = cv2.resize(s2,(100,100))
# ----> 6     pred = KNN(X,Y,c1,10)
#       7     print(pred)
#       8     #plt.subplot(2,5,i+1)
#
# <ipython-input-315-3ca752e74578> in KNN(X, Y, test_point, k)
#       1 def KNN(X,Y,test_point,k=5):
#       2     tt =cv2.imread("Train/Images/" + X[0])
# ----> 3     t2 = cv2.resize(tt,(100,100))
#       4     m=t2.shape[0]
#       5     vals = []
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
s1
